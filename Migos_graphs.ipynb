# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
spotify_data = "Spotify Billboard Correl - Spotify.csv"

# %%
spotify_df = pd.read_csv(spotify_data)
spotify_df.head()
# Out:
#                       id          Artist      Song Title  energy  key  \
# 0  7fa9MBXhVfQ8P8Df9OEbD        Maroon 5  Girls Like You   0.541    0
# 1  6DCZcSspjsKoFjzjrWoCd           Drake      God's Plan   0.449    7
# 2  1rfofaqEpACxVEHIZBJe6  Camila Cabello          Havana   0.523    2
# 3  58q2HKrzhC3ozto2nDdN4         Cardi B       I Like It   0.726    5
# 4  2G7V7zsVDxg1yRsu7Ew9R           Drake  In My Feelings   0.626    1
#
#      tempo  danceability  loudness  mode  speechiness  ...  time_signature  \
# 0  124.959         0.851    -6.825     1       0.0505  ...               4
# 1   77.169         0.754    -9.211     1       0.1090  ...               4
# 2  104.988         0.765    -4.333     1       0.0300  ...               4
# 3  136.048         0.816    -3.998     0       0.1290  ...               4
# 4   91.030         0.835    -5.833     1       0.1250  ...               4
#
#    Peak Position  Weeks on Chart          PEAK      energy.1  \
# ...

# %%
x_energy = spotify_df ["energy"]
y_peak = spotify_df["Peak Position"]
area = np.pi*10
colors = (0,0,0)

# %%
plt.scatter(x_energy, y_peak, s=area, c=colors, alpha=0.5)
plt.title('Peak vs. Energy')
plt.xlabel('Energy Attribute')
plt.ylabel('Peak Position')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["key"]
y_peak = spotify_df["Peak Position"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_peak, s=area, c=colors, alpha=0.5)
plt.title('Peak vs. Key')
plt.xlabel('key Attribute')
plt.ylabel('Peak Position')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["tempo"]
y_peak = spotify_df["Peak Position"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_peak, s=area, c=colors, alpha=0.5)
plt.title('Peak vs. tempo')
plt.xlabel('tempo Attribute')
plt.ylabel('Peak Position')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["danceability"]
y_peak = spotify_df["Peak Position"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_peak, s=area, c=colors, alpha=0.5)
plt.title('Peak vs. danceability')
plt.xlabel('danceability Attribute')
plt.ylabel('Peak Position')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["loudness"]
y_peak = spotify_df["Peak Position"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_peak, s=area, c=colors, alpha=0.5)
plt.title('Peak vs. loudness')
plt.xlabel('loudness Attribute')
plt.ylabel('Peak Position')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["speechiness"]
y_peak = spotify_df["Peak Position"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_peak, s=area, c=colors, alpha=0.5)
plt.title('Peak vs. speechiness')
plt.xlabel('speechiness Attribute')
plt.ylabel('Peak Position')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["acousticness"]
y_peak = spotify_df["Peak Position"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_peak, s=area, c=colors, alpha=0.5)
plt.title('Peak vs. acousticness')
plt.xlabel('acousticness Attribute')
plt.ylabel('Peak Position')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["instrumentalness"]
y_peak = spotify_df["Peak Position"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_peak, s=area, c=colors, alpha=0.5)
plt.title('Peak vs. instrumentalness')
plt.xlabel('instrumentalness Attribute')
plt.ylabel('Peak Position')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["liveness"]
y_peak = spotify_df["Peak Position"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_peak, s=area, c=colors, alpha=0.5)
plt.title('Peak vs. liveness')
plt.xlabel('liveness Attribute')
plt.ylabel('Peak Position')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["valence"]
y_peak = spotify_df["Peak Position"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_peak, s=area, c=colors, alpha=0.5)
plt.title('Peak vs. valence')
plt.xlabel('valence Attribute')
plt.ylabel('Peak Position')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
###WEEKS###

# %%
x_energy = spotify_df ["energy"]
y_week = spotify_df["Weeks on Chart"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_week, s=area, c=colors, alpha=0.5)
plt.title('Week vs. Energy')
plt.xlabel('Energy Attribute')
plt.ylabel('Weeks on Charts')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["key"]
y_week = spotify_df["Weeks on Chart"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_week, s=area, c=colors, alpha=0.5)
plt.title('Week vs. Key')
plt.xlabel('key Attribute')
plt.ylabel('Weeks on Charts')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["tempo"]
y_week = spotify_df["Weeks on Chart"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_week, s=area, c=colors, alpha=0.5)
plt.title('Week vs. Tempo')
plt.xlabel('Tempo Attribute')
plt.ylabel('Weeks on Charts')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["danceability"]
y_week = spotify_df["Weeks on Chart"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_week, s=area, c=colors, alpha=0.5)
plt.title('Week vs. Danceability')
plt.xlabel('Danceability Attribute')
plt.ylabel('Weeks on Charts')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["loudness"]
y_week = spotify_df["Weeks on Chart"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_week, s=area, c=colors, alpha=0.5)
plt.title('Week vs. Loudness')
plt.xlabel('Loudness Attribute')
plt.ylabel('Weeks on Charts')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["speechiness"]
y_week = spotify_df["Weeks on Chart"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_week, s=area, c=colors, alpha=0.5)
plt.title('Week vs. Speechiness')
plt.xlabel('Speechiness Attribute')
plt.ylabel('Weeks on Charts')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["acousticness"]
y_week = spotify_df["Weeks on Chart"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_week, s=area, c=colors, alpha=0.5)
plt.title('Week vs. Acousticness')
plt.xlabel('Acousticness Attribute')
plt.ylabel('Weeks on Charts')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["instrumentalness"]
y_week = spotify_df["Weeks on Chart"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_week, s=area, c=colors, alpha=0.5)
plt.title('Week vs. instrumentalness')
plt.xlabel('instrumentalness Attribute')
plt.ylabel('Weeks on Charts')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["liveness"]
y_week = spotify_df["Weeks on Chart"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_week, s=area, c=colors, alpha=0.5)
plt.title('Week vs. liveness')
plt.xlabel('liveness Attribute')
plt.ylabel('Weeks on Charts')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
x_energy = spotify_df ["valence"]
y_week = spotify_df["Weeks on Chart"]
area = np.pi*10
colors = (0,0,0)
plt.scatter(x_energy, y_week, s=area, c=colors, alpha=0.5)
plt.title('Week vs. Valence')
plt.xlabel('Valence Attribute')
plt.ylabel('Weeks on Charts')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
